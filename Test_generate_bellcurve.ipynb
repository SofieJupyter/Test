# %%
# import modules
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import pandas as pd 
from scipy import stats

# %%
#define mean and standard deviation 
mean1 = 0
sd1 = 1

# Calculating mean and Stdev of column
df_mean = np.mean(df["Ytvikt"])
df_std = np.std(df["AGW"])

# %%
#define lower and upper bounds for x-axis
lower_bound = -4
upper_bound = 4

# %%
#create range of x-values from lower to upper bound in increments of .001
x = np.arange(lower_bound,upper_bound, 0.001)

# %%
#create range of y-values that correspond to normal pdf with mean1=0 and sd=1 
y = norm.pdf(x,0,1)

# %%
# build the plot
fig, ax = plt.subplots(figsize=(9,6))
ax.plot(x,y)
#define title for the plot
ax.set_title('Normal Gaussian Curve')
#choose plot style and display the bell curve 
plt.style.use('fivethirtyeight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
#define mean and standard deviation 
mean1 = 0
sd1 = 1
#define lower and upper bounds for x-axis
lower_bound = -4
upper_bound = 4
#create range of x-values from lower to upper bound in increments of .001
x = np.arange(lower_bound,upper_bound, 0.001)
#create range of y-values that correspond to normal pdf with mean1=0 and sd=1 
y = norm.pdf(x,0,1)
# build the plot
fig, ax = plt.subplots(figsize=(9,6))
ax.plot(x,y)
#specify the region of the bell curve to fill in 
x_fill = np.arange(-1, 1, 0.001)
y_fill = norm.pdf(x_fill,0,1)
ax.fill_between(x_fill,y_fill,0, alpha=0.2, color='red')
#define title for the plot
ax.set_title('Normal Gaussian Curve')
#choose plot style and display the bell curve 
plt.style.use('seaborn-whitegrid')
plt.show()

# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Sofie_K_test3.xlsx')

# %%
#df_mean = df.groupby(['Körning'])["Ytvikt"].mean()
#df_std = df.groupby(['Körning'])["Ytvikt"].std()

df_mean = df["Ytvikt"].mean()
df_std = df["Ytvikt"].std()
df_mean
df_std
# Out:
# 26.576301286200867

# %%
df_gbKörning_Ytvikt = df.groupby(['Körning'])['Ytvikt']

# %%
df_48260 = df.loc[df['ProduktYtvikt'] == 'Invecote L4-260']

# %%
#group data by product and display sales as line chart
df_48260.groupby('Körning')['Ytvikt'].plot(legend=True)
# Out:
# Körning
# 2022-01-01_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-02-02_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-02-17_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-03-15_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-03-16_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-04-10_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-05-01_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-05-22_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-05-23_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-06-14_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-07-04_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Ytvikt, dtype: object

# %%
df_48260.groupby(['Körning'])['Ytvikt'].plot(kind = "kde")
# Out:
# Körning
# 2022-01-01_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-02-02_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-02-17_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-03-15_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-03-16_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-04-10_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-05-01_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-05-22_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-05-23_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-06-14_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-07-04_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Ytvikt, dtype: object

# %%
df_48260.groupby(['Körning'])['Ytvikt'].plot(kind = "kde")
plt.xlim([240,280])
plt.title('Ytvikt-48260', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Ytvikt-48260')

# %%
df_jan = df.loc[df['MånadKörning'] == 'jan']
df_feb = df.loc[df['MånadKörning'] == 'feb']
df_mar= df.loc[df['MånadKörning'] == 'mar']
df_apr = df.loc[df['MånadKörning'] == 'apr']
df_maj = df.loc[df['MånadKörning'] == 'maj']
df_jun = df.loc[df['MånadKörning'] == 'jun']
df_jul = df.loc[df['MånadKörning'] == 'jul']

df_maj_48260 = df_maj.loc[df['ProduktYtvikt'] == 'Invecote L4-260']


df_maj_48260.groupby(['Körning'])['Ytvikt'].plot(kind = "kde")
plt.xlim([240,280])
# Out:
# (240.0, 280.0)

# %%
pip install nbconvert[webpdf]
# Out:
#   Input In [4]
#     pip install nbconvert[webpdf]
#         ^
# SyntaxError: invalid syntax

# %%
pip install pyppeteer--allow-chromium-download
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pyppeteer--allow-chromium-download (from versions: none)
# ERROR: No matching distribution found for pyppeteer--allow-chromium-download

# %%
choco install pandoc
# Out:
#   Input In [7]
#     choco install pandoc
#           ^
# SyntaxError: invalid syntax

# %%
nbconvert --to pdf notebook.ipynb
# Out:
#   Input In [9]
#     nbconvert --to pdf notebook.ipynb
#                    ^
# SyntaxError: invalid syntax

# %%
bp = df_maj_48260.boxplot(column=['Ytvikt'], by='Körning', color='black') 
plt.gcf().set_size_inches(10, 10)
plt.ylim([250,280])
plt.ylabel('Ytvikt', fontsize=18)
plt.title('48260 ')
plt.axhline(247, color='r')
plt.axhline(255, color='b')
plt.axhline(260, color='g')
plt.axhline(265, color='b')
plt.axhline(273, color='r')
meds = [df_maj_48260.groupby('Körning').Ytvikt.median()]
cnts = [df_maj_48260.groupby('Körning').Ytvikt.count()]
plt.xticks(rotation=90)

for tick,label in zip(range(len(meds[0])) , bp.get_xticklabels()):
    bp.text(tick+2, 
            meds[0][tick+1], 
            cnts[0][tick+1], 
            horizontalalignment='center', color='blue', weight='bold')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [23], in <cell line: 15>()
#      13 plt.xticks(rotation=90)
#      15 for tick,label in zip(range(len(meds[0])) , bp.get_xticklabels()):
#      16     bp.text(tick+2,
# ---> 17             meds[0][tick+1],
#      18             cnts[0][tick+1],
#      19             horizontalalignment='center', color='blue', weight='bold')
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:955, in Series.__getitem__(self, key)
#     952     key = unpack_1tuple(key)
#     954 if is_integer(key) and self.index._should_fallback_to_positional:
# --> 955     return self._values[key]
#     957 elif key_is_scalar:
#     958     return self._get_value(key)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
@interact
interact        (dateselectro,
                 start_date=widgets.DatePicker(value=pd.to_datetime('2018-01-01')),
        end_date=widgets.DatePicker(value=pd.to_datetime('2019-01-01')))

df.boxplot(column=['Ytvikt'], by='Körning', color='black') 
plt.gcf().set_size_inches(30, 10)
plt.ylim([250,280])
plt.ylabel('Ytvikt', fontsize=18)
plt.title('48260 ')
plt.axhline(247, color='r')
plt.axhline(255, color='b')
plt.axhline(260, color='g')
plt.axhline(265, color='b')
plt.axhline(273, color='r')
# Out:
#   Input In [32]
#     interact        (dateselectro,
#     ^
# SyntaxError: invalid syntax

# %%
df_48260.groupby(['Körning'])['Ytvikt'].plot(kind = "kde")
plt.xlim([240,280])
plt.title('Ytvikt-48260', fontsize=18)
plt.xlabel('g/m2')
plt.axvline(247, color='r')
plt.axvline(255, color='b')
plt.axvline(260, color='g')
plt.axvline(265, color='b')
plt.axvline(273, color='r')
#plt.legend()
#plt.legend(bbox_to_anchor=(1.5,1))
#plt.legend(bbox_to_anchor=(x,y) , loc='center left')
plt.legend(title='Körning',title_fontsize=10,loc='center left', bbox_to_anchor=(1,0.5))

bp = df_48260.boxplot(column=['Ytvikt'], by='Körning', color='black') 
#plt.gcf().set_size_inches(10, 10)
plt.ylim([250,280])
plt.ylabel('Ytvikt', fontsize=18)
plt.title('48260 ')
plt.axhline(247, color='r')
plt.axhline(255, color='b')
plt.axhline(260, color='g')
plt.axhline(265, color='b')
plt.axhline(273, color='r')
meds = [df_48260.groupby('Körning').Ytvikt.median()]
cnts = [df_48260.groupby('Körning').Ytvikt.count()]
plt.xticks(rotation=90)

for tick,label in zip(range(len(meds[0])) , bp.get_xticklabels()):
    bp.text(tick+2, 
            meds[0][tick+1], 
            cnts[0][tick+1], 
            horizontalalignment='center', color='blue', weight='bold')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [58], in <cell line: 29>()
#      27 plt.xticks(rotation=90)
#      29 for tick,label in zip(range(len(meds[0])) , bp.get_xticklabels()):
#      30     bp.text(tick+2,
# ---> 31             meds[0][tick+1],
#      32             cnts[0][tick+1],
#      33             horizontalalignment='center', color='blue', weight='bold')
#
# File ~\Anaconda3\lib\site-packages\pandas\core\series.py:955, in Series.__getitem__(self, key)
#     952     key = unpack_1tuple(key)
#     954 if is_integer(key) and self.index._should_fallback_to_positional:
# --> 955     return self._values[key]
#     957 elif key_is_scalar:
#     958     return self._get_value(key)
#
# IndexError: index 11 is out of bounds for axis 0 with size 11

# %%
import ipywidgets as widgets
import pandas as pd
style = {'description_width': 'initial'}
limit_case = widgets.IntSlider(
    value=1000,
    min=100,
    max=5000,
    step=1,
    description='Max Number of Case:',
    disabled=False,
    style=style)

# %%
# https://towardsdatascience.com/creating-an-interactive-dashboard-from-jupyter-notebook-with-voila-b64918b4d15a
#article describing how to make interaktive notebook with widgets
import pandas as pd
import ipywidgets as widgets

unique_produkt = df.ProduktYtvikt.unique()

from ipywidgets import Layout

Produkt = widgets.SelectMultiple(
    options = unique_produkt.tolist(),
  #  value = ['Invecote L4-260', 'Invecote L2-220'],
    description='Produkt',
    disabled=False,
    layout = Layout(width='50%', height='80px', display='flex')
)

Produkt
# Out:
# SelectMultiple(description='Produkt', layout=Layout(display='flex', height='80px', width='50%'), options=('Inv…

# %%
displayy=Produkt

# %%
from IPython.display import display
btn = widgets.Button(description='Medium')
display(btn)
# Out:
# Button(description='Medium', style=ButtonStyle())

# %%
pip install voila
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)'))': /packages/af/f2/52832c5e92535c40b890ac3dda41ba3cb477d2b01b79933a5eb72b275a6c/voila-0.3.6-py3-none-any.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self signed certificate in certificate chain (_ssl.c:1129)'))': /packages/af/f2/52832c5e92535c40b890ac3dda41ba3cb477d2b01b79933a5eb72b275a6c/voila-0.3.6-py3-none-any.whl
# ...

# %%
df_48260.groupby(['Körning'])['Tjocklek'].plot(kind = "kde")
# Out:
# Körning
# 2022-01-01_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-02-02_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-02-17_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-03-15_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-03-16_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-04-10_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-05-01_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-05-22_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-05-23_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-06-14_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# 2022-07-04_48260    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Tjocklek, dtype: object

# %%
grouped =df.groupby("Körning")
grouped[["Ytvikt", "Tjocklek"]].plot(kind='kde')
# Out:
# C:\Users\IBSOBE\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:184: RuntimeWarning: All-NaN slice encountered
#   sample_range = np.nanmax(y) - np.nanmin(y)
# C:\Users\IBSOBE\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:186: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(y) - 0.5 * sample_range,
# C:\Users\IBSOBE\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\hist.py:187: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(y) + 0.5 * sample_range,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 grouped =df.groupby("Körning")
# ----> 2 grouped[["Ytvikt", "Tjocklek"]].plot(kind='kde')
#
# File ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:543, in GroupByPlot.__call__(self, *args, **kwargs)
#     540     return self.plot(*args, **kwargs)
# ...

# %%
df_48260.groupby(['Körning'])['Ytvikt']

# %%
df_48260.groupby(['Körning'])['Ytvikt'].size().plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='Körning'>

# %%
df_22220 = df.loc[df['ProduktYtvikt'] == 'Invecote L2-220']

# %%
gp_df_22220 = df_22220.groupby("Körning")

# %%
# Calculating probability density function (PDF)
df_mean = df.groupby(['Körning'])["Ytvikt"].mean()
df_std = df.groupby(['Körning'])["Ytvikt"].std()
pdf = stats.norm.pdf(gp_df_22220["Ytvikt"].sort_values(), df_mean, df_std)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 4>()
#       2 df_mean = df.groupby(['Körning'])["Ytvikt"].mean()
#       3 df_std = df.groupby(['Körning'])["Ytvikt"].std()
# ----> 4 pdf = stats.norm.pdf(gp_df_22220["Ytvikt"].sort_values(), df_mean, df_std)
#
# File ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'sort_values'

# %%
# Calculating probability density function (PDF)
pdf = stats.norm.pdf(df["Ytvikt"].sort_values(), df_mean, df_std)
# Drawing a graph
plt.plot(df["Ytvikt"].sort_values(), pdf)
plt.xlim([150,350])  
plt.xlabel("Ytvikt", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
df['mean'] = df.groupby(['Körning'])["Ytvikt"].mean()
df['std'] = df.groupby(['Körning'])["Ytvikt"].std()
df
# Out:
#                     Time           Körning          StartDatum MånadKörning  \
# 0    2022-01-01 10:00:00  2022-01-01_48260 2022-01-01 10:00:00          jan
# 1    2022-01-01 11:00:00  2022-01-01_48260 2022-01-01 10:00:00          jan
# 2    2022-01-01 12:00:00  2022-01-01_48260 2022-01-01 10:00:00          jan
# 3    2022-01-01 13:00:00  2022-01-01_48260 2022-01-01 10:00:00          jan
# 4    2022-01-01 14:00:00  2022-01-01_48260 2022-01-01 10:00:00          jan
# ...                  ...               ...                 ...          ...
# 4520 2022-07-11 05:00:00  2022-07-10_47230 2022-07-10 22:00:00          jul
# 4521 2022-07-11 06:00:00  2022-07-10_47230 2022-07-10 22:00:00          jul
# 4522 2022-07-11 08:00:00  2022-07-11_22220 2022-07-11 08:00:00          jul
# 4523 2022-07-11 09:00:00  2022-07-11_22220 2022-07-11 08:00:00          jul
# 4524 2022-07-11 10:00:00  2022-07-11_22220 2022-07-11 08:00:00          jul
#
# ...

# %%
df_mean = df.groupby(['Körning'])["Ytvikt"].mean()
df_std = df.groupby(['Körning'])["Ytvikt"].std()
df_mean
# Out:
# Körning
# 2022-01-01_48260                                           262.194603
# 2022-01-05_28220                                           220.048334
# 2022-01-05_44920                                                  NaN
# 2022-01-07_28240                                           241.048313
# 2022-01-19_22220                                           219.367391
#                                           ...
# 2022-07-10_47230                                           235.577083
# 2022-07-10_47250                                           252.033333
# 2022-07-10_47270                                           276.924999
# 2022-07-11_22220                                           217.149999
# mean                Körning
# 2022-01-01_48260    262.194603
# 2022-01...
# Name: Ytvikt, Length: 120, dtype: object

# %%
grouped =df.groupby("Körning")
grouped[["Ytvikt", "Tjocklek"]].agg([np.mean, np.std])
# Out:
#                       Ytvikt               Tjocklek
#                         mean        std        mean        std
# Körning
# 2022-01-01_48260  262.194603   5.930194  350.712302   2.263707
# 2022-01-05_28220  220.048334   1.928055  278.856250   3.018234
# 2022-01-05_44920         NaN        NaN         NaN        NaN
# 2022-01-07_28240  241.048313   1.974871  311.408951   3.318442
# 2022-01-19_22220  219.367391   1.965656  277.456522   3.268003
# ...                      ...        ...         ...        ...
# 2022-07-09_47300  307.035418   1.812882  398.000000   2.887095
# 2022-07-10_47230  235.577083   2.727578  303.093750   2.580908
# 2022-07-10_47250  252.033333   1.609796  329.020833   1.950739
# 2022-07-10_47270  276.924999  10.331431  355.445833  14.614293
# 2022-07-11_22220  217.149999        NaN  276.000000        NaN
#
# [119 rows x 4 columns]

# %%
df_grouped = grouped[["Ytvikt", "Tjocklek"]].agg([np.mean, np.std])
df_grouped
# Out:
#                       Ytvikt               Tjocklek
#                         mean        std        mean        std
# Körning
# 2022-01-01_48260  262.194603   5.930194  350.712302   2.263707
# 2022-01-05_28220  220.048334   1.928055  278.856250   3.018234
# 2022-01-05_44920         NaN        NaN         NaN        NaN
# 2022-01-07_28240  241.048313   1.974871  311.408951   3.318442
# 2022-01-19_22220  219.367391   1.965656  277.456522   3.268003
# ...                      ...        ...         ...        ...
# 2022-07-09_47300  307.035418   1.812882  398.000000   2.887095
# 2022-07-10_47230  235.577083   2.727578  303.093750   2.580908
# 2022-07-10_47250  252.033333   1.609796  329.020833   1.950739
# 2022-07-10_47270  276.924999  10.331431  355.445833  14.614293
# 2022-07-11_22220  217.149999        NaN  276.000000        NaN
#
# [119 rows x 4 columns]

# %%
df.plot.bar();
# Out:
# Error in callback <function flush_figures at 0x000002F8B5289940> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:121, in flush_figures()
#     118 if InlineBackend.instance().close_figures:
#     119     # ignore the tracking, just draw and close all figures
#     120     try:
# --> 121         return show(True)
#     122     except Exception as e:
#     123         # safely show traceback if in IPython, else raise
#     124         ip = get_ipython()
#
# File ~\Anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
# ...

# %%
# Calculating probability density function (PDF) och lägg till den kollumnen i df
grouped =df.groupby("Körning")

# %%
df
# Out:
#                     Time           Körning          StartDatum MånadKörning  \
# 0    2022-01-01 10:00:00  2022-01-01_48260 2022-01-01 10:00:00          jan
# 1    2022-01-01 11:00:00  2022-01-01_48260 2022-01-01 10:00:00          jan
# 2    2022-01-01 12:00:00  2022-01-01_48260 2022-01-01 10:00:00          jan
# 3    2022-01-01 13:00:00  2022-01-01_48260 2022-01-01 10:00:00          jan
# 4    2022-01-01 14:00:00  2022-01-01_48260 2022-01-01 10:00:00          jan
# ...                  ...               ...                 ...          ...
# 4520 2022-07-11 05:00:00  2022-07-10_47230 2022-07-10 22:00:00          jul
# 4521 2022-07-11 06:00:00  2022-07-10_47230 2022-07-10 22:00:00          jul
# 4522 2022-07-11 08:00:00  2022-07-11_22220 2022-07-11 08:00:00          jul
# 4523 2022-07-11 09:00:00  2022-07-11_22220 2022-07-11 08:00:00          jul
# 4524 2022-07-11 10:00:00  2022-07-11_22220 2022-07-11 08:00:00          jul
#
# ...

# %%
#df_mean = df.groupby(['Körning'])["Ytvikt"].mean()
#df_std = df.groupby(['Körning'])["Ytvikt"].std()

df_mean = df["Ytvikt"].mean()
df_std = df["Ytvikt"].std()
# Calculating probability density function (PDF)
pdf = stats.norm.pdf(df["Ytvikt"].sort_values(), df_mean, df_std)
# Drawing a graph
plt.plot(df["Ytvikt"].sort_values(), pdf)
plt.xlim([150,350])  
plt.xlabel("Ytvikt", size=12)    
plt.ylabel("Frequency", size=12)                
plt.grid(True, alpha=0.3, linestyle="--")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

d = {'ID': [1, 1, 1, 2, 2, 3, 3, 3, 4],
     'name': ['bob', 'bob', 'bob', 'shelby', 'shelby', 'jordan', 'jordan', 'jordan', 'jeff'],
     'type': ['type1', 'type2', 'type4', 'type1', 'type6', 'type5', 'type8', 'type2', None]}
df: pd.DataFrame = pd.DataFrame(data=d)

df_pivot: pd.DataFrame = df.pivot_table(index='type', columns=['name'], values='ID', aggfunc={'ID': np.sum}).fillna(0)
df_pivot: pd.DataFrame = df.pivot_table(index='Körning', columns=['name'], values='ID', aggfunc={'ID': np.sum}).fillna(0)

# create percent totals of the specific type's row of the total
df_pivot['bob_pct_total']: pd.Series = df_pivot['bob'].sum()
df_pivot['shelby_pct_total']: pd.Series = (df_pivot['shelby'] / df_pivot['shelby'].sum()).mul(100).round(1)
df_pivot['jordan_pct_total']: pd.Series = (df_pivot['jordan'] / df_pivot['jordan'].sum()).mul(100).round(1)
df_pivot['name_pct_unique']: pd.Series = df['name'].nunique()
#df_pivot['name_pct_unique']: pd.Series = grouped['Aktuellt tamburnummer KM1~^1~^2~^1'].nunique()

fig, ax = plt.subplots(figsize=(12, 5))
columns = ['bob', 'jordan', 'shelby']
df_pivot.plot(kind='bar', y=['bob', 'jordan', 'shelby'], rot=0, ax=ax)
for bars, col in zip(ax.containers, ['bob_pct_total', 'name_pct_unique', 'shelby_pct_total']):
    ax.bar_label(bars, labels=['' if val == 0 else f'{val}' for val in df_pivot[col]])
plt.tight_layout()
plt.show()

# %%
df_pivot
# Out:
# name   bob  jordan  shelby  bob_pct_total  shelby_pct_total  jordan_pct_total  \
# type
# type1  1.0     0.0     2.0            3.0              50.0               0.0
# type2  1.0     3.0     0.0            3.0               0.0              33.3
# type4  1.0     0.0     0.0            3.0               0.0               0.0
# type5  0.0     3.0     0.0            3.0               0.0              33.3
# type6  0.0     0.0     2.0            3.0              50.0               0.0
# type8  0.0     3.0     0.0            3.0               0.0              33.3
#
# name   name_pct_unique
# type
# type1                4
# type2                4
# type4                4
# type5                4
# type6                4
# type8                4
